# %% [markdown]
# # How much is the business selling?

# %% [markdown]
# # Where are customers buying more?

# %% [markdown]
# # Where is average order value highest?

# %% [markdown]
# # What are customers buying?

# %% [markdown]
# # What does each region prefer?

# %% [markdown]
# # Who are the highest-value customers?

# %% [markdown]
# # What factors appear to influence purchasing behavior?

# %% [markdown]
# # What should the business do based on the findings..
