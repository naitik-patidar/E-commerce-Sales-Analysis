# %% [markdown]
# # How much is the business selling?
#
# Ans - Total reveue : 20667120

# %% [markdown]
# # Where are customers buying more?
# Ans - Region wise : North with 25.5 % (all over)
#     Category wise : Electronics are the ihighest selling category

# %% [markdown]
# # Where is average order quantity value, lowest and highest ?
#
# Ans ; average order quantity : 4
#     lowest  : 1
#     highest : 7

# %% [markdown]
# # What are customers buying?
# Ans ; Electronics items mostly with 35.5 % then clothing items 30.6 %.

# %% [markdown]
# # What does each region prefer?
# Ans ; Mostly the distribution is same for all the region.

# %% [markdown]
# # Who are the highest-value customers?
# Ans - the one who are in top 25% tile with there average order value of 1515.69 rs.

# %% [markdown]
# # What should the business do based on the findings..
