# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("ecommerce_sales_analysis.csv", encoding="latin1")

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 1        10002   1/2/2022         1435         Clothing  South         7
# 2        10003   1/3/2022         1860           Beauty   East         3
# 3        10004   1/4/2022         1270      Electronics   West         5
# 4        10005   1/5/2022         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996   9/5/2035         1289         Clothing   West         2
# 4996     14997   9/6/2035         1294           Beauty  North         3
# 4997     14998   9/7/2035         1450           Beauty   West         3
# 4998     14999   9/8/2035         1903      Electronics  South         4
# 4999     15000   9/9/2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
clean_df = df[["customer_id", "product_category","region", "quantity", "unit_price", "discount", "delivery_days", "customer_rating", "revenue" ]]

# %%
clean_df
# Out:
#       customer_id product_category region  quantity  unit_price  discount  \
# 0            1102           Beauty  South         7      373.65      0.28
# 1            1435         Clothing  South         7       47.74      0.09
# 2            1860           Beauty   East         3      311.28      0.31
# 3            1270      Electronics   West         5      524.47      0.02
# 4            1106         Clothing   West         5      139.87      0.33
# ...           ...              ...    ...       ...         ...       ...
# 4995         1289         Clothing   West         2      371.74      0.27
# 4996         1294           Beauty  North         3      553.67      0.14
# 4997         1450           Beauty   West         3       77.22      0.24
# 4998         1903      Electronics  South         4      138.41      0.21
# 4999         1214             Home   East         7      231.58      0.34
#
#       delivery_days  customer_rating  revenue
# ...

# %%
clean_df.describe()
# Out:
#        customer_id     quantity   unit_price     discount  delivery_days  \
# count  5000.000000  5000.000000  5000.000000  5000.000000    5000.000000
# mean   1505.701200     4.044800   308.418774     0.179984       6.118800
# std     290.836902     2.020398   169.259369     0.101404       3.153264
# min    1000.000000     1.000000    15.150000     0.000000       1.000000
# 25%    1253.000000     2.000000   161.895000     0.090000       3.000000
# 50%    1510.000000     4.000000   309.890000     0.180000       6.000000
# 75%    1761.000000     6.000000   455.557500     0.270000       9.000000
# max    1999.000000     7.000000   599.960000     0.350000      11.000000
#
#        customer_rating      revenue
# count      5000.000000  5000.000000
# mean          2.973980  1021.955148
# std           1.157722   825.584219
# min           1.000000    11.210000
# 25%           2.000000   354.527500
# 50%           3.000000   796.650000
# 75%           4.000000  1515.690000
# ...

# %% [markdown]
# # Calculate the main KPIs
#  • Total revenue
#  • Total orders
#  • Total customers
#  • Total quantity sold
#  • Average order value
#  • Average customer rating
#  • Average delivery time

# %%
clean_df.describe().loc['mean',['revenue', "unit_price", "discount", "delivery_days" ]]
# Out:
# revenue          1021.955148
# unit_price        308.418774
# discount            0.179984
# delivery_days       6.118800
# Name: mean, dtype: float64
